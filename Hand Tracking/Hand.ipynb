# %%
import cv2
import mediapipe as mp
import time
import HandTrackingModule as htm

pTime = 0
cTime = 0
cap = cv2.VideoCapture(1)
detector = htm.handDetector()

while True:
    success, img = cap.read()
    img = detector.findHands(img, draw = False)
    lmList = detector.findPosition(img, draw = False)
    if len(lmList) != 0:
        print(lmList[4])

    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime

    cv2.putText(img,str(int(fps)),(10,50),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3)


    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# [4, 338, 19]
# [4, 370, 16]
# [4, 390, 0]
# [4, 387, -9]
# [4, 374, -1]
# [4, 354, -1]
# [4, 343, -6]
# [4, 336, -7]
# [4, 320, -9]
# [4, 299, -10]
# [4, 290, -9]
# [4, 293, -6]
# [4, 286, -7]
# [4, 278, -7]
# [4, 292, -6]
# [4, 301, -5]
# [4, 303, -5]
# [4, 297, 1]
# [4, 279, 2]
# [4, 274, 3]
# [4, 254, -6]
# [4, 256, -6]
# [4, 255, -6]
# [4, 249, 0]
# [4, 248, 7]
# [4, 252, 11]
# [4, 260, 15]
# [4, 258, 15]
# [4, 252, 15]
# [4, 251, 14]
# [4, 250, 18]
# [4, 251, 18]
# [4, 251, 20]
# [4, 253, 22]
# [4, 255, 25]
# [4, 256, 27]
# [4, 253, 33]
# [4, 249, 37]
# [4, 246, 39]
# [4, 239, 40]
# [4, 231, 43]
# [4, 224, 48]
# [4, 215, 48]
# [4, 207, 49]
# [4, 199, 55]
# [4, 194, 63]
# [4, 189, 71]
# [4, 183, 76]
# [4, 179, 81]
# [4, 173, 85]
# [4, 171, 87]
# [4, 170, 89]
# [4, 171, 90]
# [4, 173, 92]
# [4, 175, 94]
# [4, 180, 100]
# [4, 190, 117]
# [4, 200, 129]
# [4, 213, 136]
# [4, 221, 137]
# [4, 217, 124]
# [4, 212, 115]
# [4, 198, 102]
# [4, 188, 81]
# [4, 188, 62]
# [4, 188, 48]
# [4, 187, 38]
# [4, 188, 29]
# [4, 189, 24]
# [4, 193, 27]
# [4, 198, 33]
# [4, 203, 42]
# [4, 209, 48]
# [4, 209, 53]
# [4, 211, 60]
# [4, 218, 66]
# [4, 225, 68]
# [4, 226, 70]
# [4, 225, 68]
# [4, 219, 66]
# [4, 216, 64]
# [4, 213, 63]
# [4, 211, 61]
# [4, 214, 61]
# [4, 215, 63]
# [4, 218, 60]
# [4, 221, 56]
# [4, 223, 52]
# [4, 227, 48]
# [4, 227, 43]
# [4, 228, 41]
# [4, 225, 35]
# [4, 224, 32]
# [4, 221, 29]
# [4, 223, 24]
# [4, 226, 16]
# [4, 228, 16]
# [4, 233, 22]
# [4, 235, 29]
# [4, 235, 38]
# [4, 230, 53]
# [4, 230, 71]
# [4, 229, 112]
# [4, 249, 126]
# [4, 267, 126]
# [4, 282, 98]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-96f81d22a8b1> in <module>
#      10
#      11 while True:
# ---> 12     success, img = cap.read()
#      13     img = detector.findHands(img, draw = False)
#      14     lmList = detector.findPosition(img, draw = False)
#
# KeyboardInterrupt:
